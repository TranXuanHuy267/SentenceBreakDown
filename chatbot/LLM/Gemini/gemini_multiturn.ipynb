# %%
import json
import requests
requests.packages.urllib3.disable_warnings() 
api_key = "AIzaSyAkwVWJqOPPAIPYKctH9Y8XuVHrR9I5JwQ"
url = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?key={api_key}"
safetySettings =  [
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_NONE"
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_NONE"
    },
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_NONE"
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_NONE"
    }
]
session = requests.Session()
session.verify = False

# %%
def update_history(chat_history):
    chat_contents = []
    for chat_pair in chat_history:
        chat_contents.append({
            "role": "user",
            "parts": [
                {
                    "text": chat_pair[0]
                }
            ]
        })
        chat_contents.append({
            "role": "model",
            "parts": [
                {
                    "text": chat_pair[1]
                }
            ]
        })
    return chat_contents

# %%
def chatbot(chat_history, session, safetySettings, question):
    contents = update_history(chat_history)
    contents.append({
        "role": "user",
        "parts": [
            {
                "text": question
            }
        ]
    })
    payload = json.dumps({
        "contents": contents,
        "safetySettings": safetySettings
    })
    headers = {
        'Content-Type': 'application/json'
    }
    response = session.request("POST", url, headers=headers, data=payload)
    answer = json.loads(response.text)['candidates'][0]['content']['parts'][0]['text']
    chat_history.append((question, answer))
    return response, chat_history

# %%
chat_history = []

# %%
question = "Can you give some python code to show more about the difference between keyword arguments and positional arguments?"
question = "Can you give code for dev tools in kibana to get all index?"
question = "Can you write the python code that get all data of a index in elasticsearch with http://10.207.188.20:8220/?"
question = "I get the following error: ApiError: ApiError(406, 'Content-Type header [application/vnd.elasticsearch+json; compatible-with=8] is not supported', 'Content-Type header [application/vnd.elasticsearch+json; compatible-with=8] is not supported')"
question = 'Our version of python elasticsearch is 8.11.1'
question = "Do you know this error? Error: raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(elasticsearch.BadRequestError: BadRequestError(400, 'search_phase_execution_exception', 'failed to create query: [knn] queries are only supported on [dense_vector] fields')"
question = "Can you create some dense vector?"
question = 'How to zip a folder in a server?'
question = 'How to integrate RAG with elasticsearch? Which framework should I use?'
question = 'Can you write python code for search by embedding using elasticsearch?'
question = 'Can you fix the above code with the index that have field "embedding"?'
question = 'Can you explain more about each feature in cosineSimilarity above?'
question = "I get the following error: BadRequestError: BadRequestError(400, 'illegal_argument_exception', 'Required [query]')"
question = 'Can you write the python code that search an elasticsearch using embedding? This index has feature embedding'
question = "BadRequestError: BadRequestError(400, 'parsing_exception', 'Unknown key for a START_OBJECT in [script_score].')"
question = 'Can you write the python code that search an elasticsearch using embedding? This index has "embedding" field that presents the embedding of text'
question = 'Can you write python code for search by embedding using elasticsearch?'
question = "BadRequestError: BadRequestError(400, 'search_phase_execution_exception', 'runtime error')"
question = """
    Here are python code for search a index of elasticsearch by text. Can you give me the code for search by embedding?
    def searchByText(text, index_name):
        query = {
            'query': {
                'match': {
                    'text': text
                }
            }
        }
        results = client.search(index=index_name, body=query)
        
        # Print the results
        for hit in results['hits']['hits']:
            print(hit['_source']['text'])
            print(hit['_score'])
            print('-'*30)

    searchByText('Tại sao nên lắp camera giám sát cho gia đình?', 'homecamera')
"""
question = "Bạn có biết Elasticsearch có thể search bằng text và bằng embedding không?"
question = ("Bạn có thể viết code python để search bằng cả text và embedding cho một lần query elasticsearch không?")
question = "Làm sao để trả về score khi search cả bằng text và embedding?"
question = "Do you know Nguyễn Duy Long?"
question = "How old is he?"
question = "Can you write python code for a web ui using streamlit like chatgpt"

# %%
response, chat_history = chatbot(chat_history, session, safetySettings, question)

for chat_pair in chat_history:
    print("User: "+chat_pair[0])
    print("Gemini: "+chat_pair[1])
    print('-'*30)
# Out:
# User: Can you write python code for a web ui using streamlit and fastapi like chatgpt
# Gemini: ```python
# # Import the necessary libraries.
# import streamlit as st
# from fastapi import FastAPI, Request, WebSocket, WebSocketDisconnect
# from fastapi.responses import HTMLResponse
# from fastapi.templating import Jinja2Templates
# from pydantic import BaseModel
#
# # Define the FastAPI app.
# app = FastAPI()
# templates = Jinja2Templates(directory="templates")
#
# # Define the WebSocket endpoint.
# @app.websocket("/ws")
# async def websocket_endpoint(websocket: WebSocket):
#     await websocket.accept()
#
#     # Receive messages from the client.
#     while True:
#         try:
#             data = await websocket.receive_json()
#             print(f"Received message: {data}")
#
#             # Send a message back to the client.
#             await websocket.send_json({"message": "Hello from the server!"})
#         except WebSocketDisconnect:
#             break
#
# ...

# %%
# !pip install --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org --proxy=http://proxy-tct:3128 streamlit
# Out:
# ...
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/e9/07/63a6e890c9b998a6318b46c2a34377fd1a3e01a94c427d82bfb2472b7c16/streamlit-1.30.0-py2.py3-none-any.whl.metadata
# ...
#      - 0 bytes ? 0:00:00
#      - 8.2 kB ? 0:00:00
# ...
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/c5/e4/7fcceef127badbb0d644d730d992410e4f3799b295c9964a172f92a469c7/altair-5.2.0-py3-none-any.whl.metadata
# ...
#      - 0 bytes ? 0:00:00
#      - 8.7 kB ? 0:00:00
# ...
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/fa/2a/7f3714cbc6356a0efec525ce7a0613d581072ed6eb53eb7b9754f33db807/blinker-1.7.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for cachetools<6,>=4.0 from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
# ...

# %%
import streamlit as st
from streamlit.components.v1 import html

# Define the Streamlit app.
def main():
    # Create a title for the app.
    st.title("ChatGPT Web UI")

    # Create a text input for the user to enter their prompt.
    prompt = st.text_input("Enter your prompt:")

    # Create a button for the user to submit their prompt.
    submit_button = st.button("Submit")

    # Send the prompt to the ChatGPT API when the button is clicked.
    if submit_button:
        # Import the ChatGPT API client.
        import openai

        # Set your OpenAI API key.
        openai.api_key = "YOUR_API_KEY"

        # Send the prompt to the API and get the response.
        response = openai.Completion.create(
            prompt=prompt,
            model="text-davinci-003",
            temperature=0.7,
            max_tokens=1024
        )

        # Display the response from the API.
        st.write(response["choices"][0]["text"])

# Run the app.
if __name__ == "__main__":
    main()
